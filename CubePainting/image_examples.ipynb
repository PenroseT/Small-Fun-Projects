# %%
import cube_image_transform as cit

# %%
image_original = cit.read_image("images/image_a.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_a")

# %%
image_original = cit.read_image("images/image_b.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_b")

# %%
image_original = cit.read_image("images/image_c.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_c")

# %%
image_original = cit.read_image("images/image_d.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_d")

# %%
image_original = cit.read_image("images/image_e.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_e")

# %%
image_original = cit.read_image("images/image_f.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_f")

# %%
image_original = cit.read_image("images/image_g.jpg")
scarce_palette = cit.load_my_palette2(equal=True)
cit.display_all(image_original, scarce_palette, imagesize=(30, 40), m=13,\
                scarcity_weight=0.95, adjust=True, nsteps=100000, save=True, name="image_g")
