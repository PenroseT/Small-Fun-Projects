# %%
import cube_image_transform as cit

# %% [raw]
# There are various algorithms used to recreate the image given the color palette.
# Sequential algorithm starts from the first pixel and goes over pixels from left to right.
# Permuted algorithm starts from a random permutation of pixels in the original image.
# Monte Carlo (MC) algorithms swap two randomly chosen pixels in the figure and check if the
# new transform matches the original image more closely.

# %%
image_original = cit.read_image("images/vangogh.jpeg")
scarce_palette = cit.load_my_palette2()

# %%
cit.display_all(image_original, scarce_palette, imagesize=(40, 30), m=13, scarcity_weight=0.9, adjust=True, nsteps=100000, save=True, name="vangogh")
